# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# !pip install langchain openai tiktoken

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings

# %%
loader = TextLoader("text.txt",encoding="utf-8")
documents = loader.load()

# %%
print(documents)
print(len(documents))
# Out:
# [Document(page_content='With Early Release ebooks, you get books in their earliest form—\nthe author’s raw and unedited content as he or she writes—so you\ncan take advantage of these technologies long before the official\nrelease of these titles. The following will be Chapter 9 in the final\nrelease of the book.\nAlthough most of the applications of Machine Learning today are based on supervised\nlearning (and as a result, this is where most of the investments go to), the vast\nmajority of the available data is actually unlabeled: we have the input features X, but\nwe do not have the labels y. Yann LeCun famously said that “if intelligence was a cake,\nunsupervised learning would be the cake, supervised learning would be the icing on\nthe cake, and reinforcement learning would be the cherry on the cake”. In other\nwords, there is a huge potential in unsupervised learning that we have only barely\nstarted to sink our teeth into.\nFor example, say you want to create a system that will
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1024,chunk_overlap= 48)
texts = text_splitter.split_documents(documents)

# %%
print(texts[0])
print(len(texts))
# Out:
# page_content='With Early Release ebooks, you get books in their earliest form—\nthe author’s raw and unedited content as he or she writes—so you\ncan take advantage of these technologies long before the official\nrelease of these titles. The following will be Chapter 9 in the final\nrelease of the book.\nAlthough most of the applications of Machine Learning today are based on supervised\nlearning (and as a result, this is where most of the investments go to), the vast\nmajority of the available data is actually unlabeled: we have the input features X, but\nwe do not have the labels y. Yann LeCun famously said that “if intelligence was a cake,\nunsupervised learning would be the cake, supervised learning would be the icing on\nthe cake, and reinforcement learning would be the cherry on the cake”. In other\nwords, there is a huge potential in unsupervised learning that we have only barely\nstarted to sink our teeth into.\nFor example, say you want to create a system that will take a fe
# ...

# %%
embeddings = OpenAIEmbeddings(api_key=openai_api_key)
vector = embeddings.embed_query("for testing embedding")

# %%
vector

# %%
# !pip install psycopg2-binary pgvector

# %%
from langchain_community.vectorstores.pgvector import PGVector

# %%
CONNECTION_STRING = "postgresql+psycopg2://postgres:admin@localhost:5432/vector_db"
COLLECTION_NAME = "Hands_On_Machine_Learning"

db = PGVector.from_documents(embedding=embeddings,documents=texts,collection_name=COLLECTION_NAME,connection_string=CONNECTION_STRING)

# %%
query = "most of the applications of Machine Learning today are based on what?"

# %%
similar = db.similarity_search_with_score(query,k=2)
for doc in similar:
    print(doc)
# Out:
# (Document(page_content='With Early Release ebooks, you get books in their earliest form—\nthe author’s raw and unedited content as he or she writes—so you\ncan take advantage of these technologies long before the official\nrelease of these titles. The following will be Chapter 9 in the final\nrelease of the book.\nAlthough most of the applications of Machine Learning today are based on supervised\nlearning (and as a result, this is where most of the investments go to), the vast\nmajority of the available data is actually unlabeled: we have the input features X, but\nwe do not have the labels y. Yann LeCun famously said that “if intelligence was a cake,\nunsupervised learning would be the cake, supervised learning would be the icing on\nthe cake, and reinforcement learning would be the cherry on the cake”. In other\nwords, there is a huge potential in unsupervised learning that we have only barely\nstarted to sink our teeth into.\nFor example, say you want to create a system that will
# ...

# %%
print(embeddings.embed_query(query))
# Out:
# [-0.005790114288271991, -0.003397042563064101, 0.018473064161612318, -0.02525398271510226, -0.009144364675354514, -0.006487956142276756, -0.004196927799737079, 0.0021544228813190143, -0.028730026809471662, -0.026992005693609517, 0.004361512984513619, 0.017446051938054475, -0.011356392650742085, 0.0033443753411885103, -0.021251266401976953, 0.012982495803703281, 0.023647630119590368, 0.0071166724421927886, 0.010783634866615249, -0.02973070495643043, -0.01598453303854726, 0.010395213756036812, -0.007630179019632989, -0.058566066209653274, 0.0035089605259650495, 0.005865823361510492, 0.023318457887392178, -0.020935263070723412, -0.010019958752435356, -0.012014734321170796, 0.030520716078531955, -0.014286012106261167, -0.01814389379205924, -0.01720904897395304, -0.021238099363677418, 0.003453001544514575, 0.01766988786385637, 0.011764564318769825, 0.003240686544394133, -0.012422905989198537, 0.014536182108662138, 0.02406896789459509, -0.0016499686427097458, -0.041422850564552804, -0.0115
# ...
